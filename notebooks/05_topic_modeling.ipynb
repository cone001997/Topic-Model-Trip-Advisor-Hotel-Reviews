# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF

df = pd.read_csv('../data/processed_data/reviews_with_clusters.csv')

df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                         Review_clean  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not  experience hotel monaco seattl...
# 3  unique great stay wonderful time hotel monaco ...
# 4  great stay great stay went seahawk game awesom...
#
#                                        Review_tokens  \
# 0  ['nice', 'hotel', 'expensive', 'parking', 'got...
# 1  ['ok', 'nothing', 'special', 'charge', 'diamon...
# 2  ['nice', 'rooms', 'not', 'experience', 'hotel'...
# 3  ['unique', 'great', 'stay', 'wonderful', 'time...
# 4  ['great', 'stay', 'great', 'stay', 'went', 'se...
#
#                                      Review_filtered  \
# 0  ['nice', 'hotel', 'expensive', 'parking', 'got...
# 1  ['ok', 'nothing', 'special', 'charge', 'diamon...
# 2  ['nice', 'rooms', 'experience', 'hotel', 'mona...
# 3  ['unique', 'great', 'stay', 'wonderful', 'time...
# 4  ['great', 'stay', 'great', 'stay', 'went', 'se...
#
#                                    Review_lemmatized  \
# 0  ['nice', 'hotel', 'expensive', 'parking', 'get...
# 1  ['ok', 'nothing', 'special', 'charge', 'diamon...
# 2  ['nice', 'room', 'experience', 'hotel', 'monac...
# 3  ['unique', 'great', 'stay', 'wonderful', 'time...
# 4  ['great', 'stay', 'great', 'stay', 'go', 'seah...
#
#                                       Cleaned_Review  Review_word_count  \
# 0  nice hotel expensive parking get good deal sta...                 80
# 1  ok nothing special charge diamond member hilto...                230
# 2  nice room experience hotel monaco seattle good...                199
# 3  unique great stay wonderful time hotel monaco ...                 85
# 4  great stay great stay go seahawk game awesome ...                178
#
#    cluster                  cluster_name
# 0        2  Room Comfort & Sleep Quality
# 1        2  Room Comfort & Sleep Quality
# 2        2  Room Comfort & Sleep Quality
# 3        2  Room Comfort & Sleep Quality
# 4        2  Room Comfort & Sleep Quality
